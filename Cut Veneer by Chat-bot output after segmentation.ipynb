# %% [markdown]
# # Asking chat-bots to cut annotated (segmented) image in lines.

# %%
from matplotlib import image
from matplotlib import pyplot as plt

# %%
# to read the image, download it in colab notebook every time on execution
original_image = image.imread('290x620.jpg')

# %%
# example: to draw a line from (200,300) to (500,100)
# example: to draw a line from (x0, y0) to (x1, y1)
# x = [200, 500]
# y = [300, 100]

# %%
for line in lines:
  x = [line["x_start"], line["x_end"]]
  y = [line["y_start"], line["y_end"]]
  plt.plot(x, y, color="white", linewidth=3)

plt.imshow(original_image)
plt.show()

# %% [markdown]
# Далі йде просто склад різних варіантів, які вертали чат-бот

# %%
lines = [
  {
    "id": "cut_1_top",
    "x_start": 0,
    "y_start": 100,
    "x_end": 594,
    "y_end": 100
  },
  {
    "id": "cut_2_bottom",
    "x_start": 0,
    "y_start": 950,
    "x_end": 594,
    "y_end": 950
  },
  {
    "id": "cut_3_left",
    "x_start": 100,
    "y_start": 0,
    "x_end": 100,
    "y_end": 1159
  },
  {
    "id": "cut_4_right",
    "x_start": 500,
    "y_start": 0,
    "x_end": 500,
    "y_end": 1159
  }
]

# %%
lines = [
  {
    "id": "cut_1_horizontal_top",
    "x_start": 0,
    "y_start": 200,
    "x_end": 594,
    "y_end": 200
  },
  {
    "id": "cut_2_horizontal_bottom",
    "x_start": 0,
    "y_start": 800,
    "x_end": 594,
    "y_end": 800
  },
  {
    "id": "cut_3_vertical_left",
    "x_start": 250,
    "y_start": 200,
    "x_end": 250,
    "y_end": 800
  },
  {
    "id": "cut_4_vertical_right",
    "x_start": 300,
    "y_start": 200,
    "x_end": 300,
    "y_end": 800
  }
]
